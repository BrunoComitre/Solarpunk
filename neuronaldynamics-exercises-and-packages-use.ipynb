# %% [markdown]
# # Quickstart

# %% [markdown]
# **Installing**

# %%
# Principals
# !pip install numpy
# !pip install matplotlib
# !pip install scipy
# !pip install ipywidgets
# !pip install mne
# !pip install pandas

# %%
# To verify
# !pip install mpmath
# !pip install setuptools
# !pip install setuptools-scm  # Não está instalando
# !pip install mock
# !pip install nose

# %%
#Configs
# %matplotlib inline

import pandas as pd
pd.set_option('display.max_columns', 100)

# %%
print("Conda and Python Version")
# !conda --version && python --version
print("Which Python")
# !which python
print("Which Python")
# !which pip

print("Sys Version")
import sys
print(sys.version)

# !python -c "import mne; mne.sys_info()"

# !python -c "import sys; print(sys.executable)"

# !python -c "import mne; mne.cuda.init_cuda(verbose=True)"
# Out:
# Conda and Python Version
# conda 4.9.2
# Python 3.7.9
# Which Python
# /opt/conda/bin/python
# Which Python
# /opt/conda/bin/pip
# Sys Version
# 3.7.9 | packaged by conda-forge | (default, Feb 13 2021, 20:03:11)
# [GCC 9.3.0]
# Platform:      Linux-5.4.120+-x86_64-with-debian-buster-sid
# Python:        3.7.9 | packaged by conda-forge | (default, Feb 13 2021, 20:03:11)  [GCC 9.3.0]
# Executable:    /opt/conda/bin/python
# CPU:           x86_64: 4 cores
# Memory:        17.6 GB
#
# mne:           0.22.0
# numpy:         1.19.5 {blas=openblas, lapack=openblas}
# scipy:         1.5.4
# matplotlib:    3.4.0 {backend=agg}
#
# sklearn:       0.24.1
# numba:         0.52.0
# nibabel:       3.2.1
# nilearn:       0.7.1
# dipy:          1.4.0
# cupy:          Not found
# pandas:        1.2.2
# mayavi:        Not found
# pyvista:       Not found
# vtk:           9.0.1
# PyQt5:         5.12.3
# /opt/conda/bin/python
# CUDA not enabled in config, skipping initialization

# %% [markdown]
# ### Estudar

# %%
# Ver utilização do Conda
# !conda config --add channels conda-forge
# !conda config --set channel_priority true
# !conda update --all

# Ver utilização do Neurodinex
# !pip install --upgrade neurodynex3
# !conda install -c brian-team -c epfl-lcn neurodynex
# !conda create --name neurodynex -c brian-team -c epfl-lcn neurodynex spyder
# !source activate neurodynex

# Ver utilização do Brian2
# !conda install -c conda-forge brian2
# !conda config --add channels conda-forge
# !conda install brian2

# Ver utilização do Cupy
# !pip install cupy-cuda92

# Ver utilização do Mayavi
# !pip install mayavi
# !pip install PyQt5

# %% [markdown]
# ***
